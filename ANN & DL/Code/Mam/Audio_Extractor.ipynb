# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt 
import keras
import tensorflow

# %%
audio,sr = librosa.load(r'D:\University\University Work\Semestor 5\Ann & DL\LAB\ANN & DL\Code\Mam\harvard.wav\harvard.wav',sr=None)

# %%
print(f'Sample Rate: {sr}')
# Out:
# Sample Rate: 44100

# %%
plt.Figure(figsize=(12, 4))
librosa.display.waveshow(audio, sr=sr)
plt.title('Waveform of audio')
plt.tight_layout()
plt.show()

# %% [markdown]
# # fixed sound sample rate min 16k

# %%
audio,sr = librosa.load(r'D:\University\University Work\Semestor 5\Ann & DL\LAB\ANN & DL\Code\Mam\harvard.wav\harvard.wav', sr=16000) 
mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)
mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
librosa.display.specshow(mel_spectrogram_db, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram (dB)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Chromagram

# %%
Chromagram = librosa.feature.chroma_stft(y=audio, sr=sr)
Chromagram_db = librosa.power_to_db(Chromagram, ref=np.max)

Chromagram.shape
# Out:
# (12, 574)

# %%
frames = range(Chromagram.shape[1])
frames
# Out:
# range(0, 574)

# %%
times = librosa.frames_to_time(frames, sr=sr)
times
# Out:
# array([ 0.   ,  0.032,  0.064,  0.096,  0.128,  0.16 ,  0.192,  0.224,
#         0.256,  0.288,  0.32 ,  0.352,  0.384,  0.416,  0.448,  0.48 ,
#         0.512,  0.544,  0.576,  0.608,  0.64 ,  0.672,  0.704,  0.736,
#         0.768,  0.8  ,  0.832,  0.864,  0.896,  0.928,  0.96 ,  0.992,
#         1.024,  1.056,  1.088,  1.12 ,  1.152,  1.184,  1.216,  1.248,
#         1.28 ,  1.312,  1.344,  1.376,  1.408,  1.44 ,  1.472,  1.504,
#         1.536,  1.568,  1.6  ,  1.632,  1.664,  1.696,  1.728,  1.76 ,
#         1.792,  1.824,  1.856,  1.888,  1.92 ,  1.952,  1.984,  2.016,
#         2.048,  2.08 ,  2.112,  2.144,  2.176,  2.208,  2.24 ,  2.272,
#         2.304,  2.336,  2.368,  2.4  ,  2.432,  2.464,  2.496,  2.528,
#         2.56 ,  2.592,  2.624,  2.656,  2.688,  2.72 ,  2.752,  2.784,
#         2.816,  2.848,  2.88 ,  2.912,  2.944,  2.976,  3.008,  3.04 ,
#         3.072,  3.104,  3.136,  3.168,  3.2  ,  3.232,  3.264,  3.296,
# ...

# %%
librosa.display.specshow(Chromagram_db, x_axis='time', y_axis='chroma', sr=sr)
plt.colorbar(format='%+2.0f dB')
plt.title('Chromagram (dB)')
plt.tight_layout()
plt.show()
