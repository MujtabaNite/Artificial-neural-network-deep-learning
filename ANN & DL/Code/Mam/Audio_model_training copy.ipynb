# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Simple parameters
SAMPLE_RATE = 16000
AUDIO_LENGTH = 16000
FEATURE_DIM = 16000  # Raw audio dimension

# %%
train_set,test_set = tf.keras.utils.audio_dataset_from_directory(
    directory=r'D:\\University\\University Work\\Semestor 5\\Ann & DL\\LAB\\ANN & DL\\Data\\Audio\\archive\\Cleaned Audio Dataset',
    batch_size=16,
    validation_split=0.2,
    seed=0,
    subset='both',
    output_sequence_length=16000
)
# Out:
# Found 1435 files belonging to 28 classes.
# Using 1148 files for training.
# Using 287 files for validation.
# Using 1148 files for training.
# Using 287 files for validation.

# %%
label_names = np.array(train_set.class_names)
label_names
# Out:
# array(['Ain', 'Alif', 'Ba', 'Dad', 'Dal', 'Fa', 'Ghain', 'Ha', 'Ha2',
#        'Jeem', 'Kaf', 'Kha', 'Lam', 'Meem', 'Noon', 'Qaf', 'Ra', 'Sad',
#        'Seen', 'Sheen', 'Ta', 'Taa', 'Thaa', 'Thal', 'Waw', 'Ya', 'Zaa',
#        'Zay'], dtype='<U5')

# %%
def sequeeze(audio,labels):
    audio = tf.squeeze(audio,axis=-1)
    return audio,labels

# %%
train_set = train_set.map(sequeeze,tf.data.AUTOTUNE)
test_set = test_set.map(sequeeze,tf.data.AUTOTUNE)

# %%
# Normalize audio (data is already batched from audio_dataset_from_directory)
def normalize_audio(audio, labels):
    # Normalize to [-1, 1]
    audio = audio / (tf.reduce_max(tf.abs(audio)) + 1e-7)
    # Flatten from (batch, 16000) to (batch, 16000)
    audio = tf.reshape(audio, [tf.shape(audio)[0], FEATURE_DIM])
    return audio, labels

train_set = train_set.map(normalize_audio, tf.data.AUTOTUNE)
test_set = test_set.map(normalize_audio, tf.data.AUTOTUNE)

# %%
# Get number of classes
num_classes = len(label_names)
print(f"Number of classes: {num_classes}")
print(f"Class names: {label_names}")
# Out:
# Number of classes: 28
# Class names: ['Ain' 'Alif' 'Ba' 'Dad' 'Dal' 'Fa' 'Ghain' 'Ha' 'Ha2' 'Jeem' 'Kaf' 'Kha'
#  'Lam' 'Meem' 'Noon' 'Qaf' 'Ra' 'Sad' 'Seen' 'Sheen' 'Ta' 'Taa' 'Thaa'
#  'Thal' 'Waw' 'Ya' 'Zaa' 'Zay']

# %%
# Build simple MLP model
def create_cnn_model(num_classes):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(FEATURE_DIM,)),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

# Create the model
model = create_cnn_model(num_classes)
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 512)            │     8,192,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 28)             │         3,612 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,360,348 (31.89 MB)
#  Trainable params: 8,360,348 (31.89 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define training parameters
LEARNING_RATE = 0.001
EPOCHS = 50
EARLY_STOPPING_PATIENCE = 10
LR_REDUCE_PATIENCE = 5
MIN_LR = 0.00001

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Model compiled successfully!")
# Out:
# Model compiled successfully!

# %%
# Define model save paths
MODEL_CHECKPOINT_PATH = 'best_audio_model.keras'
MODEL_FINAL_PATH = r'D:\\University\\University Work\\Semestor 5\\Ann & DL\\LAB\\ANN & DL\\Model\\Mam\\audio_cnn_model.keras'
HISTORY_PATH = r'D:\\University\\University Work\\Semestor 5\\Ann & DL\\LAB\\ANN & DL\\Model\\Mam\\training_history.json'

# %%
# Train the model
history = model.fit(
    train_set,
    epochs=EPOCHS,
    validation_data=test_set,
    verbose=1
)
# Out:
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.2474 - loss: 2.9325 - val_accuracy: 0.0453 - val_loss: 3.3555
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.2474 - loss: 2.9325 - val_accuracy: 0.0453 - val_loss: 3.3555
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.4355 - loss: 2.6060 - val_accuracy: 0.0557 - val_loss: 3.3871
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.4355 - loss: 2.6060 - val_accuracy: 0.0557 - val_loss: 3.3871
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.5601 - loss: 2.2856 - val_accuracy: 0.0697 - val_loss: 3.4525
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.5601 - loss: 2.2856 - val_accuracy: 0.0697 - val_loss: 3.4525
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.6498 - loss: 1.9558 - val_accuracy: 0.0732 - val_loss: 3.5774
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.6498 - loss: 1.9558 - val_accuracy: 0.0732 - val_loss: 3.5774
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.7361 - loss: 1.6164 - val_accuracy: 0.0801 - val_loss: 3.7166
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.7361 - loss: 1.6164 - val_accuracy: 0.0801 - val_loss: 3.7166
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.7944 - loss: 1.2952 - val_accuracy: 0.0801 - val_loss: 3.8478
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.7944 - loss: 1.2952 - val_accuracy: 0.0801 - val_loss: 3.8478
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.8441 - loss: 1.0417 - val_accuracy: 0.0836 - val_loss: 4.0524
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.8441 - loss: 1.0417 - val_accuracy: 0.0836 - val_loss: 4.0524
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.8807 - loss: 0.8350 - val_accuracy: 0.0836 - val_loss: 4.2583
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.8807 - loss: 0.8350 - val_accuracy: 0.0836 - val_loss: 4.2583
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9059 - loss: 0.6591 - val_accuracy: 0.0801 - val_loss: 4.4594
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9059 - loss: 0.6591 - val_accuracy: 0.0801 - val_loss: 4.4594
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9260 - loss: 0.5451 - val_accuracy: 0.0801 - val_loss: 4.6640
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9260 - loss: 0.5451 - val_accuracy: 0.0801 - val_loss: 4.6640
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9425 - loss: 0.4511 - val_accuracy: 0.0697 - val_loss: 4.8685
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9425 - loss: 0.4511 - val_accuracy: 0.0697 - val_loss: 4.8685
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9486 - loss: 0.3698 - val_accuracy: 0.0662 - val_loss: 5.1048
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9486 - loss: 0.3698 - val_accuracy: 0.0662 - val_loss: 5.1048
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - accuracy: 0.9530 - loss: 0.3129 - val_accuracy: 0.0732 - val_loss: 5.2348
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - accuracy: 0.9530 - loss: 0.3129 - val_accuracy: 0.0732 - val_loss: 5.2348
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9599 - loss: 0.2463 - val_accuracy: 0.0697 - val_loss: 5.4879
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9599 - loss: 0.2463 - val_accuracy: 0.0697 - val_loss: 5.4879
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9556 - loss: 0.2436 - val_accuracy: 0.0627 - val_loss: 5.6477
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9556 - loss: 0.2436 - val_accuracy: 0.0627 - val_loss: 5.6477
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9634 - loss: 0.1922 - val_accuracy: 0.0453 - val_loss: 5.8555
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9634 - loss: 0.1922 - val_accuracy: 0.0453 - val_loss: 5.8555
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9625 - loss: 0.1760 - val_accuracy: 0.0557 - val_loss: 5.9835
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9625 - loss: 0.1760 - val_accuracy: 0.0557 - val_loss: 5.9835
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9599 - loss: 0.1664 - val_accuracy: 0.0627 - val_loss: 6.1895
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9599 - loss: 0.1664 - val_accuracy: 0.0627 - val_loss: 6.1895
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9713 - loss: 0.1420 - val_accuracy: 0.0627 - val_loss: 6.2771
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9713 - loss: 0.1420 - val_accuracy: 0.0627 - val_loss: 6.2771
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9625 - loss: 0.1300 - val_accuracy: 0.0697 - val_loss: 6.3911
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9625 - loss: 0.1300 - val_accuracy: 0.0697 - val_loss: 6.3911
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9678 - loss: 0.1339 - val_accuracy: 0.0592 - val_loss: 6.5211
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9678 - loss: 0.1339 - val_accuracy: 0.0592 - val_loss: 6.5211
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9660 - loss: 0.1370 - val_accuracy: 0.0557 - val_loss: 6.5990
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9660 - loss: 0.1370 - val_accuracy: 0.0557 - val_loss: 6.5990
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9608 - loss: 0.1129 - val_accuracy: 0.0592 - val_loss: 6.6866
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9608 - loss: 0.1129 - val_accuracy: 0.0592 - val_loss: 6.6866
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9625 - loss: 0.1137 - val_accuracy: 0.0523 - val_loss: 6.7809
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9625 - loss: 0.1137 - val_accuracy: 0.0523 - val_loss: 6.7809
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9713 - loss: 0.1001 - val_accuracy: 0.0523 - val_loss: 6.8970
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9713 - loss: 0.1001 - val_accuracy: 0.0523 - val_loss: 6.8970
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9686 - loss: 0.0853 - val_accuracy: 0.0557 - val_loss: 7.0015
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9686 - loss: 0.0853 - val_accuracy: 0.0557 - val_loss: 7.0015
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9608 - loss: 0.0947 - val_accuracy: 0.0557 - val_loss: 7.1367
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9608 - loss: 0.0947 - val_accuracy: 0.0557 - val_loss: 7.1367
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9652 - loss: 0.1141 - val_accuracy: 0.0557 - val_loss: 7.1240
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9652 - loss: 0.1141 - val_accuracy: 0.0557 - val_loss: 7.1240
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9634 - loss: 0.1066 - val_accuracy: 0.0523 - val_loss: 7.2256
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9634 - loss: 0.1066 - val_accuracy: 0.0523 - val_loss: 7.2256
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9599 - loss: 0.1151 - val_accuracy: 0.0627 - val_loss: 7.3607
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9599 - loss: 0.1151 - val_accuracy: 0.0627 - val_loss: 7.3607
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.9695 - loss: 0.0910 - val_accuracy: 0.0627 - val_loss: 7.5489
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.9695 - loss: 0.0910 - val_accuracy: 0.0627 - val_loss: 7.5489
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9608 - loss: 0.0810 - val_accuracy: 0.0592 - val_loss: 7.5203
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9608 - loss: 0.0810 - val_accuracy: 0.0592 - val_loss: 7.5203
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9678 - loss: 0.0825 - val_accuracy: 0.0662 - val_loss: 7.6095
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9678 - loss: 0.0825 - val_accuracy: 0.0662 - val_loss: 7.6095
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.9660 - loss: 0.0776 - val_accuracy: 0.0592 - val_loss: 7.4884
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.9660 - loss: 0.0776 - val_accuracy: 0.0592 - val_loss: 7.4884
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9695 - loss: 0.0794 - val_accuracy: 0.0557 - val_loss: 7.6803
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9695 - loss: 0.0794 - val_accuracy: 0.0557 - val_loss: 7.6803
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9625 - loss: 0.0759 - val_accuracy: 0.0732 - val_loss: 7.8061
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9625 - loss: 0.0759 - val_accuracy: 0.0732 - val_loss: 7.8061
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9617 - loss: 0.0845 - val_accuracy: 0.0801 - val_loss: 7.8240
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9617 - loss: 0.0845 - val_accuracy: 0.0801 - val_loss: 7.8240
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.9713 - loss: 0.0707 - val_accuracy: 0.0732 - val_loss: 7.9033
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.9713 - loss: 0.0707 - val_accuracy: 0.0732 - val_loss: 7.9033
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.9730 - loss: 0.0660 - val_accuracy: 0.0801 - val_loss: 7.9995
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.9730 - loss: 0.0660 - val_accuracy: 0.0801 - val_loss: 7.9995
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9721 - loss: 0.0598 - val_accuracy: 0.0767 - val_loss: 8.1138
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9721 - loss: 0.0598 - val_accuracy: 0.0767 - val_loss: 8.1138
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.9652 - loss: 0.0679 - val_accuracy: 0.0732 - val_loss: 8.1480
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.9652 - loss: 0.0679 - val_accuracy: 0.0732 - val_loss: 8.1480
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.9660 - loss: 0.0650 - val_accuracy: 0.0697 - val_loss: 8.1908
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.9660 - loss: 0.0650 - val_accuracy: 0.0697 - val_loss: 8.1908
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9625 - loss: 0.0737 - val_accuracy: 0.0732 - val_loss: 8.3830
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9625 - loss: 0.0737 - val_accuracy: 0.0732 - val_loss: 8.3830
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9608 - loss: 0.0757 - val_accuracy: 0.0801 - val_loss: 8.5014
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9608 - loss: 0.0757 - val_accuracy: 0.0801 - val_loss: 8.5014
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9617 - loss: 0.0673 - val_accuracy: 0.0801 - val_loss: 8.3608
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9617 - loss: 0.0673 - val_accuracy: 0.0801 - val_loss: 8.3608
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9660 - loss: 0.0649 - val_accuracy: 0.0697 - val_loss: 8.5080
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9660 - loss: 0.0649 - val_accuracy: 0.0697 - val_loss: 8.5080
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9643 - loss: 0.0704 - val_accuracy: 0.0732 - val_loss: 8.4883
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9643 - loss: 0.0704 - val_accuracy: 0.0732 - val_loss: 8.4883
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.9608 - loss: 0.0616 - val_accuracy: 0.0801 - val_loss: 8.5115
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.9608 - loss: 0.0616 - val_accuracy: 0.0801 - val_loss: 8.5115
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.9652 - loss: 0.0575 - val_accuracy: 0.0836 - val_loss: 8.6401
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.9652 - loss: 0.0575 - val_accuracy: 0.0836 - val_loss: 8.6401
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9643 - loss: 0.0670 - val_accuracy: 0.0871 - val_loss: 8.8664
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.9643 - loss: 0.0670 - val_accuracy: 0.0871 - val_loss: 8.8664

# %%
# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True)

# Plot loss
axes[1].plot(history.history['loss'], label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Evaluate the model on test set
test_loss, test_accuracy = model.evaluate(test_set, verbose=1)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0871 - loss: 8.8664
#
# Test Loss: 8.8664
# Test Accuracy: 0.0871
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0871 - loss: 8.8664
#
# Test Loss: 8.8664
# Test Accuracy: 0.0871

# %%
# Get predictions on test set for detailed analysis
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Get all predictions
predictions = []
true_labels = []

for audio, labels in test_set:
    preds = model.predict(audio, verbose=0)
    predictions.extend(np.argmax(preds, axis=1))
    true_labels.extend(labels.numpy())

predictions = np.array(predictions)
true_labels = np.array(true_labels)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_labels, predictions, target_names=label_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          Ain       0.20      0.10      0.13        10
#         Alif       0.27      0.22      0.24        18
#           Ba       0.00      0.00      0.00        15
#          Dad       0.00      0.00      0.00        10
#          Dal       0.00      0.00      0.00         5
#           Fa       0.00      0.00      0.00        12
#        Ghain       0.00      0.00      0.00         6
#           Ha       0.00      0.00      0.00         8
#          Ha2       0.11      0.38      0.17         8
#         Jeem       0.05      0.14      0.07         7
#          Kaf       0.20      0.09      0.12        11
#          Kha       0.00      0.00      0.00         9
#          Lam       0.00      0.00      0.00         8
#         Meem       0.00      0.00      0.00         5
#         Noon       0.08      0.10      0.09        10
#          Qaf       0.11      0.07      0.09        14
#           Ra       0.11      0.08      0.09        13
#          Sad       0.17      0.08      0.11        13
#         Seen       0.50      0.29      0.36         7
#        Sheen       0.00      0.00      0.00         7
#           Ta       0.33      0.22      0.27         9
#          Taa       0.09      0.08      0.08        13
#         Thaa       0.00      0.00      0.00         8
#         Thal       0.11      0.18      0.14        22
#          Waw       0.05      0.17      0.07         6
#           Ya       0.08      0.07      0.07        15
#          Zaa       0.00      0.00      0.00         7
#          Zay       0.00      0.00      0.00        11
#
#     accuracy                           0.09       287
#    macro avg       0.09      0.08      0.08       287
# weighted avg       0.10      0.09      0.08       287
# c:\Users\silen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\silen\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# Plot confusion matrix
cm = confusion_matrix(true_labels, predictions)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Save the final model
model.save(MODEL_FINAL_PATH)
print(f"Model saved to: {MODEL_FINAL_PATH}")
# Out:
# Model saved to: D:\\University\\University Work\\Semestor 5\\Ann & DL\\LAB\\ANN & DL\\Model\\Mam\\audio_cnn_model.keras

# %%
# Save training history to a file
import json

history_dict = {
    'accuracy': [float(x) for x in history.history['accuracy']],
    'val_accuracy': [float(x) for x in history.history['val_accuracy']],
    'loss': [float(x) for x in history.history['loss']],
    'val_loss': [float(x) for x in history.history['val_loss']]
}

with open(HISTORY_PATH, 'w') as f:
    json.dump(history_dict, f, indent=4)
print(f"Training history saved to: {HISTORY_PATH}")
# Out:
# Training history saved to: D:\\University\\University Work\\Semestor 5\\Ann & DL\\LAB\\ANN & DL\\Model\\Mam\\training_history.json

# %%
# Function to predict on new audio
def predict_audio(audio_file_path):
    """
    Predict the class of an audio file
    """
    # Load audio
    audio, sr = librosa.load(audio_file_path, sr=SAMPLE_RATE)
    
    # Pad or trim
    if len(audio) < AUDIO_LENGTH:
        audio = np.pad(audio, (0, AUDIO_LENGTH - len(audio)), 'constant')
    else:
        audio = audio[:AUDIO_LENGTH]
    
    # Normalize
    audio = audio / (np.max(np.abs(audio)) + 1e-7)
    
    # Add batch dimension
    audio_input = np.expand_dims(audio, axis=0)
    
    # Predict
    prediction = model.predict(audio_input, verbose=0)
    predicted_class = np.argmax(prediction[0])
    confidence = np.max(prediction[0])
    
    return {
        'predicted_class': label_names[predicted_class],
        'confidence': float(confidence),
        'all_predictions': {label_names[i]: float(prediction[0][i]) for i in range(num_classes)}
    }

print("Prediction function created successfully!")
# Out:
# Prediction function created successfully!

# %%
# Test the model on sample audio files from test set
print("Testing on sample audio files from the test set:")
print("=" * 60)

# Get a few samples from test set
sample_count = 0
for audio_batch, label_batch in test_set.take(4):
    for i in range(min(1, audio_batch.shape[0])):
        audio_sample = audio_batch[i:i+1]
        true_label = label_batch[i].numpy()
        
        # Make prediction
        prediction = model.predict(audio_sample, verbose=0)
        predicted_class = np.argmax(prediction[0])
        confidence = np.max(prediction[0])
        
        print(f"\nSample {sample_count + 1}:")
        print(f"True Label: {label_names[true_label]}")
        print(f"Predicted Label: {label_names[predicted_class]}")
        print(f"Confidence: {confidence:.4f}")
        print(f"Match: {'✓' if predicted_class == true_label else '✗'}")
        sample_count += 1
# Out:
# Testing on sample audio files from the test set:
# ============================================================
#
# Sample 1:
# True Label: Qaf
# Predicted Label: Ghain
# Confidence: 0.3911
# Match: ✗
#
# Sample 2:
# True Label: Alif
# Predicted Label: Meem
# Confidence: 0.9069
# Match: ✗
#
# Sample 1:
# True Label: Qaf
# Predicted Label: Ghain
# Confidence: 0.3911
# Match: ✗
#
# Sample 2:
# True Label: Alif
# Predicted Label: Meem
# Confidence: 0.9069
# Match: ✗
#
# Sample 3:
# True Label: Jeem
# Predicted Label: Fa
# Confidence: 0.9543
# Match: ✗
#
# Sample 4:
# True Label: Dad
# Predicted Label: Alif
# Confidence: 0.9999
# Match: ✗
#
# Sample 3:
# True Label: Jeem
# Predicted Label: Fa
# Confidence: 0.9543
# Match: ✗
#
# Sample 4:
# True Label: Dad
# Predicted Label: Alif
# Confidence: 0.9999
# Match: ✗
