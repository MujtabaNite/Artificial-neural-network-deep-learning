# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import time

# Check GPU availability
print("TensorFlow version:", tf.__version__)
print("GPU Devices:", tf.config.list_physical_devices('GPU'))

# Simple dataset (MNIST for quick test)
(x_train, y_train), _ = keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, 28 * 28).astype("float32") / 255
y_train = keras.utils.to_categorical(y_train, 10)

# Simple ANN model
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=(784,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train briefly to test GPU performance
start = time.time()
history = model.fit(x_train, y_train, epochs=3, batch_size=128, verbose=1)
end = time.time()

print(f"\nTraining completed in {end - start:.2f} seconds")
print("GPU used:", tf.test.is_gpu_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 from tensorflow.keras import layers
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

print("TensorFlow version:", tf.__version__)
print("\n=== Available Devices ===")
print(device_lib.list_local_devices())

print("\n=== GPU Devices ===")
print(tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
#
# === Available Devices ===
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14922921712672233248
# xla_global_id: -1
# ]
#
# === GPU Devices ===
# []

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("CUDA built with TensorFlow:", tf.test.is_built_with_cuda())
print("GPU available to TensorFlow:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.17.1
# CUDA built with TensorFlow: False
# GPU available to TensorFlow: []

# %%
import tensorflow as tf

from tensorflow.python.platform import build_info as tf_build_info

print("TensorFlow version:", tf.__version__)
print("CUDA version built with TF:", tf_build_info.build_info.get('cuda_version'))
print("cuDNN version built with TF:", tf_build_info.build_info.get('cudnn_version'))
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.18.0
# CUDA version built with TF: None
# cuDNN version built with TF: None
# GPUs detected: []

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))

a = tf.random.normal([2000,2000])
b = tf.random.normal([2000,2000])
c = tf.matmul(a,b)
print(c)
# Out:
# []
# tf.Tensor(
# [[-58.32143    28.905745  -57.399822  ...  55.51292   -37.07391
#   -18.31503  ]
#  [-54.05451    16.347748  -27.156029  ...  18.055805  -35.98585
#    16.961277 ]
#  [ 47.580544   -7.929111  -50.508408  ... -11.919538    4.314399
#   -16.480412 ]
#  ...
#  [ -2.582887   37.495113  -73.005264  ...  13.07236    77.38489
#   -21.516552 ]
#  [-56.78656     8.063629  -25.62248   ...  -6.6176467  -2.19382
#    21.126793 ]
#  [ 16.734404   72.35197   -29.590654  ...  15.937784    6.8905773
#    13.856482 ]], shape=(2000, 2000), dtype=float32)

# %%
import tensorflow as tf

from tensorflow.python.platform import build_info as tf_build_info

print("TensorFlow version:", tf.__version__)
print("CUDA version built with TF:", tf_build_info.build_info.get('cuda_version'))
print("cuDNN version built with TF:", tf_build_info.build_info.get('cudnn_version'))
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.18.0
# CUDA version built with TF: None
# cuDNN version built with TF: None
# GPUs detected: []
